# %% [raw]
# Q1. Describe the differences between text and binary files in a single paragraph.
#
# Q2. What are some scenarios where using text files will be the better option? When would you like to
# use binary files instead of text files?
#
# Q3. What are some of the issues with using binary operations to read and write a Python integer
# directly to disc?
#
# Q4. Describe a benefit of using the with keyword instead of explicitly opening a file.
#
# Q5. Does Python have the trailing newline while reading a line of text? Does Python append a
# newline when you write a line of text?
#
# Q6. What file operations enable for random-access operation?
#
# Q7. When do you think you'll use the struct package the most?
#
# Q8. When is pickling the best option?
#
# Q9. When will it be best to use the shelve package?
#
# Q10. What is a special restriction when using the shelve package, as opposed to using other data
# dictionaries?

# %% [markdown]
# # Q1. Describe the differences between text and binary files in a single paragraph.

# %% [raw]
# The main difference between text files and binary files in Python is that text files store human-readable data as text, while binary files store machine-readable data as a sequence of bytes. This difference affects the way the files are manipulated in Python, as different methods and techniques are used to read, write, and manipulate each type of file.

# %% [markdown]
# # Q2. What are some scenarios where using text files will be the better option? When would you like to use binary files instead of text files?

# %% [raw]
# There are several scenarios where using text files would be a better option over binary files in Python.
# 1.Storing human-readable data: Text files are an ideal choice for storing data that can be read and understood by humans. Examples of such data include configuration files, log files, and source code files.
#
# On the other hand, there are also scenarios where using binary files would be a better option over text files.
# 1.Storing large amounts of data: Binary files are more efficient at storing large amounts of data, such as multimedia files (audio, video, images) or binary data generated by scientific simulations.

# %% [markdown]
# # Q3. What are some of the issues with using binary operations to read and write a Python integer directly to disc?

# %% [raw]
# Using binary operations to read and write a Python integer directly to disc can result in several issues, including:
# 1.Endianness.
# 2.Platform dependence.
# 3.Data corruption.
# 4.File format.
# 5.Type conversion.

# %% [markdown]
# # Q4. Describe a benefit of using the with keyword instead of explicitly opening a file.

# %% [raw]
# In Python, the with keyword provides a way to automatically manage resources such as file objects. When a file is opened using the with keyword, the file is automatically closed at the end of the block, regardless of whether an exception is raised or not. This is a significant benefit over explicitly opening a file, as it ensures that the file is properly closed, preventing any potential issues with file corruption, data loss, or system resources.

# %% [markdown]
# # Q5. Does Python have the trailing newline while reading a line of text? Does Python append a newline when you write a line of text?

# %% [raw]
# When reading a line of text using the readline() method in Python, the resulting string includes the trailing newline character (\n) if it exists in the file.
#
# When writing a line of text using the write() method in Python, the newline character is not automatically appended to the end of the line. If you want to include a newline character at the end of a line, you need to explicitly add it to the string being written

# %% [markdown]
# # Q6. What file operations enable for random-access operation?

# %% [raw]
# In Python, random-access operations on files are enabled through the following file operations:
#
# seek(offset[, whence]): This method changes the current file position. The offset argument specifies how many bytes to move the position, and the optional whence argument determines where the offset is relative to. The whence argument defaults to 0 (the beginning of the file).
#
# tell(): This method returns the current file position in bytes.
#
# read([size]): This method reads and returns up to size bytes of data from the file, starting at the current file position. If size is not specified or is negative, the entire remaining contents of the file are read and returned.
#
# write(bytes): This method writes the bytes to the file at the current file position, overwriting any existing bytes at that position. The current file position is advanced by the number of bytes written.

# %% [markdown]
# # Q7. When do you think you'll use the struct package the most?

# %% [raw]
# The struct package in Python is most commonly used when working with binary data, such as reading and writing data to and from binary files, sockets, or other sources of binary data. It allows you to convert between Python values and C-style data types that are commonly used in binary data formats, such as integers, floats, and character arrays.

# %% [markdown]
# # Q8. When is pickling the best option?

# %% [raw]
# Pickling is a good option when you need to serialize and deserialize complex Python objects, share data between processes or machines, cache expensive computations, or save and load machine learning models.

# %% [markdown]
# # Q9. When will it be best to use the shelve package?

# %% [raw]
# The shelve package can be a good choice whenever you need to store and access large amounts of data or persistent data, or when you need to cache frequently accessed data to improve performance.

# %% [markdown]
# # Q10. What is a special restriction when using the shelve package, as opposed to using other data dictionaries?

# %% [raw]
# When using the shelve package in Python, there is one special restriction that you need to be aware of: the keys used to access the data in the shelve object must be strings.
# This is in contrast to other data dictionaries in Python, such as the built-in dict type, which allows keys of any hashable type.
